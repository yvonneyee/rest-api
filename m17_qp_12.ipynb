# %% [markdown]
# <a href="https://colab.research.google.com/github/yvonneyee/rest-api/blob/colab/m17_qp_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #REQUIREMENT

# %%
# requirements
#Part ni aku rasa untuk connect or send to tele so everytime kau nak hantar to
#tele kau kena panggil function send()
import matplotlib
import matplotlib.pyplot as plt
from random import randint
from random import randint,shuffle
import random
from io import BytesIO
import base64
import requests,json
import numpy as np
from fractions import Fraction 
from matplotlib import patches
class Q_type:
  multichoice="multichoice"
  singlechoice="singlechoice"
  photo="photo"
  shortreply="shortreply"

def send(info):
  url="https://thebotserver.herokuapp.com/api/broadcast/64"
  #url="https://vocab.ngrok.io/api/broadcast/64"
  payload={
      #"message":{"photo":info},
      "message":info,
  }
  headers={
      "Content-Type":'application/json'
  }
  r=requests.request("POST",url,headers=headers,data=json.dumps(payload))
  print(r)

# %% [markdown]
# #EXAMPLE

# %%
# @title number
import math
import random
from fractions import Fraction
#atas ni dia just import untuk buat question

#ni contoh dia punya question
def number_grade7():
  #variable temp ni adalaah soalan :basically dia akan jadikan string ni (temp) as 
  #png 
  temp="""Here is a list of numbers.
  Put a ring around the number with the largest value.

  {x}

  """
  #aku rasa tiga "" untuk jadikan dia multiline string
  #kalau kau perasan {x} adalah variable : kiranya dia boleh masukkan variable 
  # into the string
  fn=(random.randint(3,9))
  x=[round(1/fn,3),Fraction(1/fn).limit_denominator(),(round(1/(fn),3)+0.01),Fraction(fn/10).limit_denominator(),str(fn)+'%']
  
  #yang ans variable ni penting sebab kau kena letak "q":what the string kau nak 
  #tukar to png and kau kena letak gak variable yang kau nak letak dalam string tu
  ans={"q":temp,"x":x}

#yang bawah ni just to convert to png
  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Yvonne"}

  # the send command is to send to the group, just make sure the cell, first cell, has been run before
#kalau nak send call fx send(fx untuk question)
number_grade7()
# Out:
# <Response [200]>

# %% [markdown]
# #m17_12 number 1 +++

# %%
import random
def m17_12_1():


  c="""1.Write the difference in temperature between
      {b} $^\circ$C and {a} $^\circ$C. 


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}
          
      Ans={answer}
  """
  a=random.randint(-100,100)
  b=random.randint(a-100,a+100)
  answer=abs(b-a)
  



  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(randint(1,100)) 
  options=list(options)
  shuffle(options)
  answer=str(abs(answer))+ r'$^\circ$C'
  ans={"q":c,"b":b,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4],}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_1()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12 number 2+
# hmmm

# %%
def m17_12_2():
  c="""2. Shade two more squares so that this shape has 
  rotational symmetry of order 2 
    
                                                                  
                                                                                           
    """

  ans={"q":c}


  N = 8
  data = np.ones((N, N)) * np.nan
  data[4,1:6]=1
  data[5,2]=1
  data[5,5]=1
  fig, ax = plt.subplots(1, 1, tight_layout=True)
  my_cmap = matplotlib.colors.ListedColormap(['0.75'])
  my_cmap.set_bad(color='w', alpha=0)

  for x in range(N + 1):
      ax.axhline(x, lw=2, color='k', zorder=5)
      ax.axvline(x, lw=2, color='k', zorder=5)
  ax.imshow(data, interpolation='none', cmap=my_cmap, extent=[0, N, 0, N], zorder=0)
  print (type(ax))
  ax.text(0, 1, ans['q'].format(**ans), horizontalalignment='left',verticalalignment='center', transform=ax.transAxes)
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}
m17_12_2()
# Out:
# <class 'matplotlib.axes._subplots.AxesSubplot'>
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
for j in range(3)[::-1]:
    data[N//2 - j : N//2 + j +1, N//2 - j : N//2 + j +1] = j
    print (j)
print (data)

print (5//2)
# Out:
# 2
# 1
# 0
# [[nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan]
#  [nan nan  2.  2.  2.  2.  2. nan nan]
#  [nan nan  2.  1.  1.  1.  2. nan nan]
#  [nan nan  2.  1.  0.  1.  2. nan nan]
#  [nan nan  2.  1.  1.  1.  2. nan nan]
#  [nan nan  2.  2.  2.  2.  2. nan nan]
#  [nan nan nan nan nan nan nan nan nan]
#  [nan nan nan nan nan nan nan nan nan]]
# 2.5

# %% [markdown]
# #m17_12_3+++

# %%
def m17_12_3a():


  c="""3.Find the value of :
      
        {a}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                                                           
          answer:{answer_a}

  """
  a2=random.randint(2,30)
  a1=a2**2
  a=r'$\sqrt{'+str(a1)+'}$'


  options=set()
  options.add(a2)

  while len(options)<5:
    options.add(abs(a2+randint(-10,10)))
  options=list(options)
  shuffle(options)



  ans={"q":c,"a":a,"answer_a":a2,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"HAFIZ"}

m17_12_3a()
# Out:
# {'Author': 'HAFIZ',
#  'Type': 'photo',
# ...

# %%
def m17_12_3b():


  c="""3.Find the value of :
       {f}
                                                         
          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                                                           
          answer:{answer}
  """
  a1=random.randint(2,30)**2
  a=r'$\sqrt{'+str(a1)+'}$'
  b=random.randint(1,9)/10.0
  d=b
  e=random.randint(1,100) 
  g=random.randint(2,4)
  f=r'$\frac{'+str(e)+'}{'+str(d)+'^'+str(g)+'}$'
  answer=round(e/(d**g),2)

  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(abs(answer+randint(-10,10)))
  options=list(options)
  shuffle(options)


  ans={"q":c,"f":f,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"HAFIZ"}
m17_12_3b()
# Out:
# {'Author': 'HAFIZ',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_4+++

# %%
import random
def m17_12_4():


  c="""4.A cuboid has dimensions {a} m by {b} m by {d} m.
   Find the volume of the cuboid. 
  
          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                                                           
          answer:{answer}
                                                                
                                                                                             ....................C[1]
  """
  a=random.randint(10,30)
  b=random.randint(10,30)
  d=random.randint(10,30)
  answer=a*b*d
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(abs(answer+(randint(-20,20)*100)))
  options=list(options)
  shuffle(options)
  ans={"q":c,"b":b,"a":a,"d":d,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_4()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_5+++

# %%
import random
def m17_12_5():


  c="""5. {a}


    Calculate the mean of these {count} numbers.
  

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                                                           
          answer:{answer}
                                                                
                                                                                             ....................C[1]
  """
  a="     "
  d=[]
  count=0
  for i in range(random.randint(5,10)):
    b=random.randint(1,100)
    d.append(b)
    a=a+"   "+str(b)
    count+=1
  answer=sum(d)/len(d)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(abs(answer+(randint(-20,20))))
  options=list(options)
  shuffle(options)
 
  ans={"q":c,"a":a,"count":count,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_5()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_6++
# ada bug kat 6A dengan B  tpi tak pasti apa

# %%
import random
import decimal
def m17_12_6a():


  c="""6.a. Write {a} in standard form.

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {answer}
  

  """
  box=[10,100,1000,10000]
  a=random.randint(1,1000)*box[random.randint(0,3)]
  b=a

  count=0
  while(b>10):
    count+=1
    b/=10
  print (a)
  print (count)
  print (b)

  answer=str(b)+"x10"+r'$^'+str(count)+'$'
  print(answer)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(str(b)+"x10"+r'$^'+str(count-random.randint(-3,3))+'$')
  options=list(options)
  shuffle(options)

  ans={"q":c,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_6a()
# Out:
# 285000
# 5
# 2.85
# 2.85x10$^5$
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
import random
import decimal
def m17_12_6b():


  c="""6. b.Write {d} x10{f} as an ordinary number.


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {answer} 
                                                                
                                                                                             ....................C[1]
  """
  box=[10,100,1000,10000,100000]
  b=decimal.Decimal(random.uniform(1, 10))
  d=round(b, random.randint(1,4))
  e=str(d)
  f1=random.randint(2,7)
  f=r'$^{'+str(f1)+'}$'
  answer=round(d*10**f1,0)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(round(d*10**(f1+random.randint(-3,3)),0))
  options=list(options)
  shuffle(options)



 
  ans={"q":c,"d":d,"f":f,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_6b()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_7+++

# %%
def m17_12_7():


  c="""7.A circular plate has diameter {a} cm.
 Calculate the circumference of the plate
  
          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {answer}
                                                                
                                                                                      
  """
  a=random.randint(10,100)
  radius = a/2.0
  answer = 2*3.14*radius
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(2*3.14*(radius+(random.randint(-5,10))))
  options=list(options)
  shuffle(options)
  ans={"q":c,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_7()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_8+++

# %%
import decimal
import random
def m17_12_8():


  answ="""8.Without using your calculator and by rounding each number correct 
  to 1 significant figure, estimate the value in 2 decimal point of 
                               





          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
  

  answer:{answer}
                                                                
 
  """
  ax=decimal.Decimal(random.uniform(10, 100))
  ay=round(ax,1)
  az=round(ay,-1)
  a=str(ay)
  bx=decimal.Decimal(random.uniform(10, 100))
  by=round(bx,1)
  bz=round(by,-1)
  b=str(by)
  cx=decimal.Decimal(random.uniform(60, 100))
  cy=round(cx,1)
  cz=round(cy,-1)
  c=str(cy)
  dx=decimal.Decimal(random.uniform(10, 50))
  dy=round(dx,1)
  dz=round(dy,-1)
  d=str(dy)
  x=r'$\frac{'+a+'x'+b+'}{'+c+'-'+d+'}$'
  answer=round(az*bz/(cz-dz),2)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(answer+(random.randint(-100,100)))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,2,2])
  plt.xlim(0.2,2)
  plt.ylim(0.2,2)
  plt.axis("off")
  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  ax.text(0.5, 1.35, x,fontsize=25, color='black')
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_8()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
answ="""8.Without using your calculator and by rounding each number correct 
to 1 significant figure, estimate the value in 2 decimal point of 
                              





        A) {o1}
        B) {o2}
        C) {o3}
        D) {o4}
        E) {o5}  


answer:{answer}
                                                              

"""
ax=decimal.Decimal(random.uniform(10, 100))
ay=round(ax,1)
az=round(ay,-1)
a=str(ay)
bx=decimal.Decimal(random.uniform(10, 100))
by=round(bx,1)
bz=round(by,-1)
b=str(by)
cx=decimal.Decimal(random.uniform(60, 100))
cy=round(cx,1)
cz=round(cy,-1)
c=str(cy)
dx=decimal.Decimal(random.uniform(10, 50))
dy=round(dx,1)
dz=round(dy,-1)
d=str(dy)
x=r'$\frac{'+a+'x'+b+'}{'+c+'-'+d+'}$'
answer=round(az*bz/(cz-dz),2)
options=set()
options.add(answer)

while len(options)<5:
  options.add(answer+(random.randint(-100,100)))
options=list(options)
shuffle(options)
ans={"q":answ,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}
fig = plt.figure()
#plt.axis("")
ax = fig.add_axes([0,0,2,2])
ax.text(0.1, 0.5, ans['q'].format(**ans),
      horizontalalignment='left',
      verticalalignment='center',
      fontsize=15, color='black',
      transform=ax.transAxes)
ax.text(0.35, 0.65, x,fontsize=25, color='black')
plt.show()

# %% [markdown]
# #m17_12_9+++

# %%
import decimal
def m17_12_9():


  answ="""9.Factorise completely.
  
            
                            {x}


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
  

  answer:{answer}
  """
  b1=random.randint(2,5)
  b2=random.randint(1,10)
  b3=random.randint(1,5)
  b4=random.randint(1,10)
  a1=b1*b3
  a2=b1*b4+b2*b3
  a3=b2*b4
  a4=2
  if b3==1:
    b3=""

  answer="("+str(b1)+"x+"+str(b2)+")("+str(b3)+"x+"+str(b4)+")"
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add("("+str(b1+random.randint(1,5))+"x+"+str(b2+random.randint(1,5))+")("+str(b3+random.randint(1,5))+"x+"+str(b4+random.randint(1,5))+")")
  options=list(options)
  shuffle(options)  

  x=str(a1)+"C"+"$^{"+str(a4)+"}$"+"+"+str(a2)+"C+"+str(a3)
  ans={"q":answ,"x":x,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_9()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
import decimal
def m17_12_9version2():


  answ="""9.Factorise completely.
  
            
                            {x}


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
  

  answer:{answer}
  """
  simp=random.randint(2,7)
  a1=random.choice([1,3,5])
  a2=random.randint(1,6)
  b1=a1*simp
  b2=a2*simp
  var=random.choice(["c","x","v","z"])
  sign=random.choice(["-","+"])

  x=str(b1)+var+"$^2$"+sign+str(b2)+var
  answer=str(random.randint(2,7))+var+"("+str(random.choice([1,3,5]))+var+sign+str(random.randint(1,6))+")"
  options=set()
  options.add(answer)

  while len(options)<5:
    opt=str(simp+random.randint(0,3))+var+"("+str(a1+random.randint(0,3))+var+sign+str(a2+random.randint(0,3))+")"
    options.add(opt)
  options=list(options)
  shuffle(options)  
  ans={"q":answ,"x":x,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_9version2()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_10+++

# %%
def m17_12_10():


  answ="""10 Find the highest common factor (HCF) of {a} and {b}.                                 
    
    
          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {answer}                                                                                             ....................C[2]
  """
  c=random.randint(15,100)
  a=c*random.randint(1,5)
  b=c*random.randint(5,10) 
  if b%a==0:
    c=a

  answer = c
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(c+(random.randint(-5,10)))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"a":a,"b":b,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_10()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_11+++

# %%
import statistics 
def m17_12_11a():


  answ="""11.     {a}    
                               
                               
            For these numbers,

            
            (a)find the range, 


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                     

            answer:{ans_a}  
                     
  """
  a="  "
  li=[]
  for i in range(random.randint(8,15)):
    b=random.randint(1,20)
    li.append(b)
    a+=str(b)+"   "
  maxi=max(li)
  mini=min(li)

  ans_a=str(mini)+" until "+str(maxi)
  options=set()
  options.add(ans_a)

  while len(options)<5:
    c=random.randint(1,6)
    options.add(str(mini+c)+" until "+str(maxi+c))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"a":a,"ans_a":ans_a,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_11a()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
import statistics 
def m17_12_11b():


  answ="""11.     {a}    
                               
                               
            For these numbers,


            (b)write down the mode. 


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  

            answer: {ans_b}                         
  """
  a="  "
  li=[]
  for i in range(random.randint(8,15)):
    b=random.randint(1,10)
    li.append(b)
    a+=str(b)+"   "
  maxi=max(li)
  mini=min(li)
  ans_b=statistics.mode(li)
  options=set()
  options.add(ans_b)

  while len(options)<5:
    c=random.randint(-6,6)
    options.add(random.choice(li))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"a":a,"ans_b":ans_b,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_11b()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_12+++

# %%
def m17_12_12():


  answ="""12.                               1 euro=$1.09  

                                    $1=62 rupees

  Change {a} euros into rupees using these exchange rates. 


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {answer}

               
  """
  a=random.randint(1,15)*100
  a=float(a)
  print(a*1.09*62.0)
  print(a)
  answer=round(a*1.09*62,1)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(answer+(random.randint(-100,300)*100))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_12()
# Out:
# 67580.0
# 1000.0
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_13+++
# done tapi saiz diaa

# %%
def m17_12_13():



  answ="""          13.    {a}    

          A) {o1}

          B) {o2}

          C) {o3}

          D) {o4}
                        
      answer: {answer}
                         
  """
  a="What is the value of X"
  b="Not to scale"

  c=random.randint(50,100)
  d=c+random.randint(20,60)
  c=c/10.0
  d=d/10.0
  answer=r"$tan^{-1}(\frac{"+str(c)+"}{"+str(d)+"})$"
  options=set()
  options.add(answer)
  options.add(r"$sin^{-1}(\frac{"+str(c)+"}{"+str(d)+"})$")
  options.add(r"$cos^{-1}(\frac{"+str(d)+"}{"+str(c)+"})$")
  options.add(r"$tan^{-1}(\frac{"+str(d)+"}{"+str(c)+"})$")

  options=list(options)
  shuffle(options)


  ans={"q":answ,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3]}
  fig = plt.figure(figsize=(6,6))
  ax = fig.add_axes([0,0,1,1])
  ax.text(0, -0.06, ans['q'].format(**ans),
      fontsize=15, color='black')
  plt.axis("off")
  fig2 = fig.add_subplot(3, 3, (1, 2))
  plt.plot([0,0,0.5,0], [0,0.35,0,0],color="black")
  plt.plot([0,0.025,0.025,0], [0,0,0.05,0.05],color="black")
  angle_plot = patches.Arc([0.6, 0.65], 0.25, 0.25, 146, 0, 27, color='black', label = str(45)+u"\u00b0")
  ax.add_patch(angle_plot)
  

  plt.text(0,0.4,"A")
  plt.text(0,-0.1,"B")
  plt.text(0.5,-0.1,"C")
  plt.text(0.33,0.03,"X\u00b0")
  plt.text(0.35,0.25,b)
  plt.text(-0.1,0.15,str(c)+"m")
  plt.text(0.2,-0.1,str(d)+"m")
  plt.axis("off")


  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_13()
# Out:
# <Response [200]>

# %% [markdown]
# #m17_12_14+++
# graf tapi saizz

# %%
def m17_12_14a():

  answ="""14.The bar chart shows the number of students
   in each of the Classes A, B, C, D and F.       
  (a) Write down how many more students there are in 
  Class D than in Class B 

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
      answer: {answer}                    
  """


  


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  a=random.randint(10,30)
  b=random.randint(10,20)
  c=random.randint(10,30)
  d=b+random.randint(1,10)
  e=0
  f=random.randint(10,30)
  answer=d-b
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(random.randint(1,10))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}
  ax.text(0.05, 0.2, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=10, color='black',
        transform=ax.transAxes)
  plt.axis("off")
  fig2 = fig.add_subplot(2, 2, (1, 1))
  height = [a, b,c, d,e,f]
  bars = ('A', 'B', 'C', 'D', 'E',"F")
  y_pos = [0,1,2,3,4,5]
  plt.bar(y_pos, height,color=(0.5, 0.5, 0.5, 0.5),width=0.3,edgecolor="black")
  plt.xticks(y_pos, bars)
  for x in range(30 + 1):
      plt.axhline(x, lw=1, color='k', zorder=5)

  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

send(m17_12_14a())
# Out:
# <Response [200]>

# %%
def m17_12_14b():

  answ="""14.The bar chart shows the number of students in 
  each of the Classes A, B, C, D and F.       
  (b) The total number of students in these six classes is {sum}.
  What is the number of students in class E?

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}              
      answer: {answer}                          
  """


  


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  a=random.randint(10,30)
  b=random.randint(10,20)
  c=random.randint(10,30)
  d=b+random.randint(1,10)
  e=0
  f=random.randint(10,30)
  e1=random.randint(10,30)
  sum=a+b+c+d+e1+f
  answer=e1
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(random.randint(10,30))
  options=list(options)
  shuffle(options)
  ans={"q":answ,"sum":sum,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  ax.text(0.05, 0.2, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=10, color='black',
        transform=ax.transAxes)
  plt.axis("off")
  fig2 = fig.add_subplot(2, 2, (1, 1))
  height = [a, b,c, d,e,f]
  bars = ('A', 'B', 'C', 'D', 'E',"F")
  y_pos = [0,1,2,3,4,5]
  plt.bar(y_pos, height,color=(0.5, 0.5, 0.5, 0.5),width=0.3,edgecolor="black")
  plt.xticks(y_pos, bars)
  for x in range(30 + 1):
      plt.axhline(x, lw=1, color='k', zorder=5)

  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

send(m17_12_14b())
# Out:
# <Response [200]>

# %% [markdown]
# #m17_12_15+++

# %%
def m17_12_15a():


  answ="""15. Write down the next term in each of these sequences.
  
  (a).{a}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {ans_a}

               
  """
  a=""
  a1=random.randint(30,50)
  a2=random.randint(2,10)
  ans_a=a1+a2*5
  answer=ans_a
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(a1+a2*random.randint(6,13))
  options=list(options)
  shuffle(options)


  for i in range(5):
    a=a+str(a1)+",    "
    a1+=a2
  a+="........................"




  ans={"q":answ,"a":a,"ans_a":ans_a,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_15a()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
def m17_12_15b():


  answ="""15. Write down the next term in each of these sequences.
  
  (b).{b}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {ans_b}

       
  """

  b=""
  b1=random.randint(0,30)
  b2=random.randint(2,10)
  ans_b=b1+b2*5
  answer=ans_b
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(b1+b2*random.randint(6,13))
  options=list(options)
  shuffle(options)



  for i in range(5):
    b=b+str(b1)+",    "
    b1+=b2
  b+="........................"


  ans={"q":answ,"b":b,"ans_b":ans_b,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_15b()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
def m17_12_15c():


  answ="""15. Write down the next term in each of these sequences.

  (c).{c}      

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
      answer: {ans_c}               
  """
  c=""
  c1=random.randint(0,30)
  c2=random.randint(2,10)
  ans_c=c1+c2*5
  answer=ans_c
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(c1+c2*random.randint(6,13))
  options=list(options)
  shuffle(options)


  for i in range(5):
    c=c+str(c1)+",    "
    c1+=c2
  c+="........................"

  ans={"q":answ,"c":c,"ans_c":ans_c,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}


  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_15c()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_16
# subjektif lukis2
# pasrah

# %%
def m17_12_16a():


  answer="""16.The angle in a semi-circle is 90

      Use the circle drawn below , with it centre marked, to show this
                      
  """

  ans={"q":answer}





  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  a_circle = plt.Circle((0, 0), radius=0.5 , ec="black", fc="white")
  plt.gca().add_patch(a_circle)
  plt.axis("scaled")
  ax.set_axis_off()

  ax.text(-0.5, 1, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_16a()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
fig, ax = plt.subplots()



a_circle = plt.Circle((0, 0), radius=0.5)

plt.gca().add_patch(a_circle)
plt.axis("scaled")
ax.set_axis_off()

# %%
def m17_12_16b():


  answer="""16.{a}
                      
  """
  a=""
  ans={"q":answer,"a":a}





  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_16b()

# %% [markdown]
# #17_12_17+++

# %%
def m17_12_17():


  answ="""17.Without using your calculator, work out  {a}{b}\u00F7{c}{d}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
  """
  a=random.randint(1,5)
  b1=random.randint(1,5)
  b2=random.randint(6,10)
  b=r'$\frac{'+str(b1)+'}{'+str(b2)+'}$'
  c=random.randint(1,5)
  d1=random.randint(1,5)
  d2=random.randint(6,10)
  d=r'$\frac{'+str(d1)+'}{'+str(d2)+'}$'
  answerrr=((a*b2+b1)*d2)/((c*d2+d1)*b2)
  answerr=Fraction((a*b2+b1)*d2,(c*d2+d1)*b2)
  answer=r'$\frac{'+str(answerr.numerator)+'}{'+str(answerr.denominator)+'}$'
  options=set()
  options.add(answer)

  while len(options)<5:
    opt=Fraction((random.randint(1,5)*random.randint(6,10)+random.randint(1,5))*random.randint(6,10),(random.randint(1,5)*random.randint(6,10)+random.randint(1,5))*random.randint(6,10))
    options.add(r'$\frac{'+str(opt.numerator)+'}{'+str(opt.denominator)+'}$')
  options=list(options)
  shuffle(options)
  
  ans={"q":answ,"a":a,"b":b,"c":c,"d":d,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_17()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_18+++

# %%
def m17_12_18a():


  answ="""18(a).Expands the bracet and simplify.
                    
                       {a}


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  a1=random.randint(2,5)
  a2=random.randint(1,5)
  a3=random.randint(1,5)
  a4=random.randint(2,5)
  a5=random.randint(1,5)
  a6=random.randint(1,5)
  word=random.choice(["w","y","x","z"])
  a=str(a1)+"("+str(a2)+word+"+"+str(a3)+")-"+str(a4)+"("+str(a5)+word+"-"+str(a6)+")"
  sign=""
  if (a1*a3-a4*a6>0):
    sign="+"
  back=a1*a3-a4*a6
  front=a1*a2-a4*a5
  if front==0:
    front=" "
  else:
    front=str(front)+word
  if back==0:
    back=""
  else:
    back=str(back)
  answer=front+sign+back
  options=set()
  options.add(answer)

  while len(options)<5:
     options.add(str(random.randint(2,15))+word+"+"+str(random.randint(2,15)))
  options=list(options)
  shuffle(options)

  
  ans={"q":answ,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_18a()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
def m17_12_18b():


  answ="""18(b).Simplify
                    
                       {a}


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  a1=random.randint(2,10)
  a2=random.randint(2,5)
  a3=random.randint(2,3)
  word=random.choice(["w","y","x","z"])
  a4=a1*(a2**a3)
  answer=str(a4)+word+"$^{"+str(a3)+"}$"
  options=set()
  options.add(answer)

  while len(options)<5:
     options.add(str(a4+random.randint(-15,100))+word+"$^{"+str(a3+random.randint(0,3))+"}$")
  options=list(options)
  shuffle(options)

  a=str(a1)+"("+str(a2)+word+")"+"$^{"+str(a3)+"}$"

  
  ans={"q":answ,"a":a,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_18b()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_19+++

# %%
def m17_12_19():


  answ="""19.   Kaasni invested ${a} at a rate of {b}% per year compound interest.
 Calculate the total value of this investment at the end of {d} years. Give your answer correct to {e} decimal places


          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  a=random.randint(5,20)
  b=random.randint(10,99)/10.0
  d=random.randint(2,9)
  e=random.randint(2,4)
  answer=a*(1+(b/100))**d
  answer=round(answer,e)
  options=set()
  options.add(answer)

  while len(options)<5:
    opt=random.randint(5,20)*(1+(random.randint(10,99)/1000))**random.randint(2,9)
    options.add(round(opt,e))
  options=list(options)
  shuffle(options)



  ans={"q":answ,"a":a,"b":b,"d":d,"e":e,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_19()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_20

# %%
def m17_12_20():


  answer="""19.   Kaasni invested ${a} at a rate of {b}.{c}% per year compound interest.
 Calculate the total value of this investment at the end of {d} years. Give your answer correct to {e} decimal places
                      
  """
  a=random.randint(2,9)
  b=random.randint(2,9)
  c=random.randint(2,9)
  d=random.randint(2,9)
  e=random.randint(2,4)

  ans={"q":answer,"a":a,"b":b,"c":c,"d":d,"e":e}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_20()

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# #m17_12_21

# %% [markdown]
# #m17_12_22+++

# %%
def m17_12_22a():


  answ="""22.Solve
  
           a.{a}x={b}
           
          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  c=random.randint(2,10)
  a=c*random.randint(2,10)
  b=c*random.randint(2,10)
  answer=float(b/a)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(random.randint(10,100)/10.0)
  options=list(options)
  shuffle(options)



  ans={"q":answ,"a":a,"b":b,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_22a()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
def m17_12_22b():


  answ="""22.Solve
  
   b.{a}(x+{b})={c}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  a=random.randint(2,9)
  b=random.randint(2,9)
  c=a*random.randint(2,9)
  answer=(c/a)-b
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(random.randint(-100,100)/10.0)
  options=list(options)
  shuffle(options)


  ans={"q":answ,"a":a,"b":b,"c":c,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}

  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_22b()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %%
def m17_12_22c():


  answ="""22.Solve
  
   c.{a}$^{b}$\u00F7{a}$^x$={c}

          A) {o1}
          B) {o2}
          C) {o3}
          D) {o4}
          E) {o5}  
                        
        
         answer:{answer}
                      
  """
  a=random.randint(2,9)
  b=random.randint(5,9)
  answer=random.randint(2,4)
  c=a**(b-answer)
  options=set()
  options.add(answer)

  while len(options)<5:
    options.add(random.randint(1,10))
  options=list(options)
  shuffle(options)


  ans={"q":answ,"a":a,"b":b,"c":c,"answer":answer,"o1":options[0],"o2":options[1],"o3":options[2],"o4":options[3],"o5":options[4]}






  fig = plt.figure()
  ax = fig.add_axes([0,0,1,1])
  plt.axis('off')

  ax.text(0.1, 0.5, ans['q'].format(**ans),
        horizontalalignment='left',
        verticalalignment='center',
        fontsize=15, color='black',
        transform=ax.transAxes)
  #this is to convert the graph to the text format to send
  image = BytesIO()
  plt.savefig(image, format='png')
  image.seek(0)
  I=base64.encodebytes(image.getvalue())
  return {"photo": I.decode(), "Type":Q_type.photo,"Author":"Hafiz"}

m17_12_22c()
# Out:
# {'Author': 'Hafiz',
#  'Type': 'photo',
# ...

# %% [markdown]
# #m17_12_23
